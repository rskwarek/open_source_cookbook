# %%
import xarray as xr
import matplotlib.pyplot as plt
import act

# %%
ds = xr.open_dataset("crocus-neiu-ceil-a1-20240505-000000.nc")

# %%
ds = xr.open_dataset("crocus-neiu-ceil-a1-20240501-000000.nc")

# %%
ds.beta_att.plot(x='time',
                 vmin=-12,
                 vmax=-6,
                 cmap='ocean')
ds.cloud_base_heights.isel(layer=0).plot(color='k', x='time')
