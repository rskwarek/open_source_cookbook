# %%
import act
import glob
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import os

# %%
files2 = glob.glob('crocus-neiu-ceilometer*')

# %%
for file in files2:
    print(file)
    ds = act.io.read_arm_netcdf(file)
    ds.backscatter.plot(x='time')
    ds.cloud_base_heights.isel(layer=0).plot(color='k', x='time')
    plt.show()
    plt.close()
# Out:
# crocus-neiu-ceilometer-a1-202306100000.nc
# crocus-neiu-ceilometer-a1-202306060000.nc
# crocus-neiu-ceilometer-a1-202306090000.nc
# crocus-neiu-ceilometer-a1-202306120000.nc
# crocus-neiu-ceilometer-a1-202306070000.nc
# crocus-neiu-ceilometer-a1-202306110000.nc
# crocus-neiu-ceilometer-a1-202306050000.nc
# crocus-neiu-ceilometer-a1-202306080000.nc
